# %% [markdown]
# # TensorFlow卷积神经网络(CNN)示例 - 原生API
# ### Convolutional Neural Network Example - Raw API

# %% [markdown]
# ## CNN网络结构图示
#
# ![CNN](http://personal.ie.cuhk.edu.hk/~ccloy/project_target_code/images/fig3.png)
#
# ## MNIST数据集
#
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# More info: http://yann.lecun.com/exdb/mnist/

# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf

# Import MNIST data，MNIST数据集导入
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("../mnist/", one_hot=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-635c2e9b8efc>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../mnist/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting ../mnist/t10k-images-idx3-ubyte.gz
# Extracting ../mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# Hyper-parameters，超参数
learning_rate = 0.001
num_steps = 1000
batch_size = 128
display_step = 10

# Network Parameters，网络参数
num_input = 784 # MNIST数据输入 (img shape: 28*28)
num_classes = 10 # MNIST所有类别 (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units = (1-p)，保留神经元相应的概率为(1-p)=(1-0.75)=0.25

# tf Graph input，TensorFlow图结构输入
X = tf.placeholder(tf.float32, [None, num_input])
Y = tf.placeholder(tf.float32, [None, num_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)，保留i

# %%
# Create some wrappers for simplicity，创建基础卷积函数，简化写法
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation，卷积层，包含bias与非线性relu激励
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper，最大池化层
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model，创建模型
def conv_net(x, weights, biases, dropout):
    # MNIST数据为维度为1，长度为784 (28*28 像素)的
    # Reshape to match picture format [Height x Width x Channel]
    # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer，卷积层
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)，最大池化层／下采样
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer，卷积层
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)，最大池化层／下采样
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer，全连接网络
    # Reshape conv2 output to fit fully connected layer input，调整conv2层输出的结果以符合全连接层的需求
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout，应用dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction，最后输出预测
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias 存储每一层的权值和全差
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, num_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# Construct model，构建模型
logits = conv_net(X, weights, biases, keep_prob)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer，定义误差函数与优化器
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)


# Evaluate model，评估模型
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)，初始化图结构所有变量
init = tf.global_variables_initializer()

# %%
# Start training，开始训练
with tf.Session() as sess:

    # Run the initializer，初始化
    sess.run(init)

    for step in range(1, num_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)，优化
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, keep_prob: dropout})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y,
                                                                 keep_prob: 1.0})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 256 MNIST test images，以每256个测试图像为例，
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: mnist.test.images[:256],
                                      Y: mnist.test.labels[:256],
                                      keep_prob: 1.0}))
# Out:
# Step 1, Minibatch Loss= 51299.0508, Training Accuracy= 0.141
# Step 10, Minibatch Loss= 20320.0352, Training Accuracy= 0.219
# Step 20, Minibatch Loss= 9776.3174, Training Accuracy= 0.539
# Step 30, Minibatch Loss= 4548.8179, Training Accuracy= 0.750
# Step 40, Minibatch Loss= 5311.1201, Training Accuracy= 0.734
# Step 50, Minibatch Loss= 4348.3281, Training Accuracy= 0.773
# Step 60, Minibatch Loss= 2821.6562, Training Accuracy= 0.812
# Step 70, Minibatch Loss= 2227.3015, Training Accuracy= 0.867
# Step 80, Minibatch Loss= 3107.2534, Training Accuracy= 0.828
# Step 90, Minibatch Loss= 1859.7069, Training Accuracy= 0.844
# Step 100, Minibatch Loss= 1312.2012, Training Accuracy= 0.914
# Step 110, Minibatch Loss= 2218.6711, Training Accuracy= 0.844
# Step 120, Minibatch Loss= 671.8196, Training Accuracy= 0.945
# Step 130, Minibatch Loss= 2451.7222, Training Accuracy= 0.867
# Step 140, Minibatch Loss= 1619.7609, Training Accuracy= 0.883
# Step 150, Minibatch Loss= 2119.3486, Training Accuracy= 0.883
# Step 160, Minibatch Loss= 840.4965, Training Accuracy= 0.930
# Step 170, Minibatch Loss= 1405.3949, Training Accuracy= 0.930
# Step 180, Minibatch Loss= 1792.0155, Training Accuracy= 0.898
# Step 190, Minibatch Loss= 758.9566, Training Accuracy= 0.906
# Step 200, Minibatch Loss= 549.9752, Training Accuracy= 0.938
# Step 210, Minibatch Loss= 1862.3911, Training Accuracy= 0.867
# Step 220, Minibatch Loss= 1348.1421, Training Accuracy= 0.914
# Step 230, Minibatch Loss= 839.5031, Training Accuracy= 0.938
# Step 240, Minibatch Loss= 1089.6101, Training Accuracy= 0.922
# Step 250, Minibatch Loss= 2198.2200, Training Accuracy= 0.891
# Step 260, Minibatch Loss= 1410.3323, Training Accuracy= 0.898
# Step 270, Minibatch Loss= 560.3518, Training Accuracy= 0.938
# Step 280, Minibatch Loss= 1116.1868, Training Accuracy= 0.914
# Step 290, Minibatch Loss= 451.7477, Training Accuracy= 0.938
# Step 300, Minibatch Loss= 872.3021, Training Accuracy= 0.930
# Step 310, Minibatch Loss= 303.5746, Training Accuracy= 0.938
# Step 320, Minibatch Loss= 473.9848, Training Accuracy= 0.953
# Step 330, Minibatch Loss= 161.4891, Training Accuracy= 0.969
# Step 340, Minibatch Loss= 1113.3818, Training Accuracy= 0.922
# Step 350, Minibatch Loss= 672.7069, Training Accuracy= 0.922
# Step 360, Minibatch Loss= 562.2218, Training Accuracy= 0.945
# Step 370, Minibatch Loss= 711.9838, Training Accuracy= 0.945
# Step 380, Minibatch Loss= 633.7622, Training Accuracy= 0.953
# Step 390, Minibatch Loss= 729.5594, Training Accuracy= 0.953
# Step 400, Minibatch Loss= 541.5375, Training Accuracy= 0.969
# Step 410, Minibatch Loss= 872.6515, Training Accuracy= 0.953
# Step 420, Minibatch Loss= 380.0000, Training Accuracy= 0.977
# Step 430, Minibatch Loss= 521.2244, Training Accuracy= 0.945
# Step 440, Minibatch Loss= 696.6287, Training Accuracy= 0.938
# Step 450, Minibatch Loss= 348.2163, Training Accuracy= 0.969
# Step 460, Minibatch Loss= 268.1496, Training Accuracy= 0.953
# Step 470, Minibatch Loss= 254.3147, Training Accuracy= 0.969
# Step 480, Minibatch Loss= 433.9114, Training Accuracy= 0.938
# Step 490, Minibatch Loss= 557.2296, Training Accuracy= 0.938
# Step 500, Minibatch Loss= 598.8654, Training Accuracy= 0.961
# Step 510, Minibatch Loss= 174.2735, Training Accuracy= 0.977
# Step 520, Minibatch Loss= 401.6613, Training Accuracy= 0.953
# Step 530, Minibatch Loss= 358.5874, Training Accuracy= 0.984
# Step 540, Minibatch Loss= 291.8170, Training Accuracy= 0.961
# Step 550, Minibatch Loss= 619.4927, Training Accuracy= 0.930
# Step 560, Minibatch Loss= 738.3203, Training Accuracy= 0.953
# Step 570, Minibatch Loss= 199.9366, Training Accuracy= 0.969
# Step 580, Minibatch Loss= 539.6356, Training Accuracy= 0.945
# Step 590, Minibatch Loss= 295.4271, Training Accuracy= 0.961
# Step 600, Minibatch Loss= 318.2692, Training Accuracy= 0.961
# Step 610, Minibatch Loss= 767.8635, Training Accuracy= 0.930
# Step 620, Minibatch Loss= 354.1588, Training Accuracy= 0.961
# Step 630, Minibatch Loss= 109.2405, Training Accuracy= 0.977
# Step 640, Minibatch Loss= 310.4529, Training Accuracy= 0.961
# Step 650, Minibatch Loss= 432.0111, Training Accuracy= 0.922
# Step 660, Minibatch Loss= 542.1269, Training Accuracy= 0.914
# Step 670, Minibatch Loss= 452.2134, Training Accuracy= 0.953
# Step 680, Minibatch Loss= 155.4736, Training Accuracy= 0.977
# Step 690, Minibatch Loss= 242.3666, Training Accuracy= 0.969
# Step 700, Minibatch Loss= 228.8467, Training Accuracy= 0.961
# Step 710, Minibatch Loss= 727.8560, Training Accuracy= 0.938
# Step 720, Minibatch Loss= 576.9518, Training Accuracy= 0.953
# Step 730, Minibatch Loss= 507.6770, Training Accuracy= 0.953
# Step 740, Minibatch Loss= 669.3571, Training Accuracy= 0.938
# Step 750, Minibatch Loss= 258.8781, Training Accuracy= 0.953
# Step 760, Minibatch Loss= 498.7035, Training Accuracy= 0.961
# Step 770, Minibatch Loss= 282.4655, Training Accuracy= 0.953
# Step 780, Minibatch Loss= 223.1361, Training Accuracy= 0.961
# Step 790, Minibatch Loss= 158.5214, Training Accuracy= 0.977
# Step 800, Minibatch Loss= 129.8322, Training Accuracy= 0.992
# Step 810, Minibatch Loss= 298.4732, Training Accuracy= 0.961
# Step 820, Minibatch Loss= 250.3173, Training Accuracy= 0.961
# Step 830, Minibatch Loss= 54.2654, Training Accuracy= 0.977
# Step 840, Minibatch Loss= 773.1432, Training Accuracy= 0.906
# Step 850, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 860, Minibatch Loss= 134.2666, Training Accuracy= 0.961
# Step 870, Minibatch Loss= 329.5463, Training Accuracy= 0.984
# Step 880, Minibatch Loss= 227.2876, Training Accuracy= 0.961
# Step 890, Minibatch Loss= 297.3494, Training Accuracy= 0.977
# Step 900, Minibatch Loss= 373.0139, Training Accuracy= 0.969
# Step 910, Minibatch Loss= 567.6917, Training Accuracy= 0.906
# Step 920, Minibatch Loss= 204.9225, Training Accuracy= 0.977
# Step 930, Minibatch Loss= 452.7331, Training Accuracy= 0.961
# Step 940, Minibatch Loss= 131.8358, Training Accuracy= 0.977
# Step 950, Minibatch Loss= 380.2451, Training Accuracy= 0.953
# Step 960, Minibatch Loss= 265.7008, Training Accuracy= 0.969
# Step 970, Minibatch Loss= 497.9948, Training Accuracy= 0.961
# Step 980, Minibatch Loss= 268.7790, Training Accuracy= 0.961
# Step 990, Minibatch Loss= 206.9182, Training Accuracy= 0.969
# Step 1000, Minibatch Loss= 607.9948, Training Accuracy= 0.938
# Optimization Finished!
# Testing Accuracy: 0.98046875
